# %% [markdown]
# TRAIN VGG16 and VGG19 MODELS ON MICC-F2000 DATASET

# %% [markdown]
# **Step:1** Download dataset on google colab disk.
# > Passing the link in function and destination folder name.

# %%
from urllib.request import urlretrieve
import os
from zipfile import ZipFile

def download(url, file):
    if not os.path.isfile(file):
        print("Download file... " + file + " ...")
        urlretrieve(url,file)
        print("File downloaded")

download('http://lci.micc.unifi.it/labd/cmfd/MICC-F2000.zip','MICC-F2000.zip')
#download('http://lci.micc.unifi.it/labd/cmfd/MICC-F220.zip','MICC-F200.zip')
#download('http://lci.micc.unifi.it/labd/cmfd/MICC-F8multi.zip','MICC-F8multi.zip')
#download('http://lci.micc.unifi.it/labd/cmfd/MICC_F600.zip','MICC-F600.zip') 
print("All the files are downloaded")

# %% [markdown]
# **Step: 2**  Unzip the downloaded files to destination folder name.

# %%
#!unzip '/content/MICC-F200.zip' -d data
# !unzip '/content/MICC-F2000.zip' -d MICC-F2000
#!unzip '/content/MICC-F8multi.zip' -d data
#!unzip '/content/MICC-F600.zip' -d data
# Out:
# Archive:  /content/MICC-F2000.zip
#    creating: MICC-F2000/MICC-F2000/
#   inflating: MICC-F2000/MICC-F2000/DSC_0097tamp10.jpg
#   inflating: MICC-F2000/MICC-F2000/DSC_0097tamp8.jpg
#   inflating: MICC-F2000/MICC-F2000/DSC_0097tamp6.jpg
#   inflating: MICC-F2000/MICC-F2000/DSC_0097tamp4.jpg
#   inflating: MICC-F2000/MICC-F2000/DSC_0097tamp3.jpg
#   inflating: MICC-F2000/MICC-F2000/DSC_0097tamp1.jpg
#   inflating: MICC-F2000/MICC-F2000/DSC_0095_01_scale.jpg
#   inflating: MICC-F2000/MICC-F2000/DSC_0093_01_scale.jpg
#   inflating: MICC-F2000/MICC-F2000/DSC_0090_scale.jpg
#   inflating: MICC-F2000/MICC-F2000/DSC_0090_01_scale.jpg
#   inflating: MICC-F2000/MICC-F2000/DSC_0088_01_scale.jpg
#   inflating: MICC-F2000/MICC-F2000/DSC_0085_01_scale.jpg
#   inflating: MICC-F2000/MICC-F2000/DSC_0083_scale.jpg
#   inflating: MICC-F2000/MICC-F2000/DSC_0083_01_scale.jpg
#   inflating: MICC-F2000/MICC-F2000/DSC_0082_01_scale.jpg
#   inflating: MICC-F2000/MICC-F2000/DSC_0081_scale.jpg
# ...

# %% [markdown]
# **Step: 3**  Create CSV file of dataset from unzipped folder of MICC-F2000 Dataset.

# %%
from pylab import *
from sklearn import preprocessing
import sys
import shutil
import random
import os
import csv


def Make_CSV_file():
        micc_2000_path =  '/content/data/MICC-F2000'
        micc_f2000 = os.listdir(micc_2000_path)
        
        file_number =random.randint(1, 1000000)
        print("Dataset prepared click Train to train the Model")
        CSV_file_name = "MICC-f2000"+"_"+str(file_number)+".csv"
        with open(CSV_file_name, "w", encoding="utf-8", newline='') as new_file:
            csv_writer = csv.writer(new_file)
            for (i, file) in enumerate(micc_f2000):
              if 'tamp' in file:
                t = 1
                csv_writer.writerow([micc_2000_path+"/" + file, t])
            for (i, file) in enumerate(micc_f2000):
              if '_scale' in file:
                t = 0
                csv_writer.writerow([micc_2000_path+"/" + file, t])
            
            #for (i, file) in enumerate(micc_f200):
              #if '_scale' in file:
                #t = 0
                #csv_writer.writerow([micc_200_path+"/" + file, t])
              #else:
                #t = 1
                #csv_writer.writerow([micc_200_path+"/" + file, t])
        print("Done")


def main():
        Make_CSV_file()
        print("Csv file has been succesfully created")
        

if __name__ == "__main__":
    main()
# Out:
# Dataset prepared click Train to train the Model
# Done
# Csv file has been succesfully

# %% [markdown]
# **Step: 4** I have CASIA v2 dataset on my google drive from there unzip .7z from dataset.

# %%
!7z e '/content/drive/My Drive/CASIA/CASIA 2.0.zip.7z'
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs AMD EPYC 7B12 (830F10),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 2650174622 bytes (2528 MiB)
#
# Extracting archive: /content/drive/My Drive/CASIA/CASIA 2.0.zip.7z
# --
# Path = /content/drive/My Drive/CASIA/CASIA 2.0.zip.7z
# Type = 7z
# Physical Size = 2650174622
# Headers Size = 130
# Method = LZMA2:24
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       2672270059
# Compressed: 2650174622

# %% [markdown]
# **Step: 5**  Unzip Casia 2.0 datasetand in return you will get Au and Tp folders on google colab containing authentic and tampered images respectively.
#
# > Indented block
#
# > Indented block
#
# > Indented block

# %%
# !unzip '/content/CASIA 2.0.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Tp/Tp_D_CRN_M_N_arc00045_arc00071_10087.tif
#   inflating: Tp/Tp_D_CRN_M_N_arc00046_arc00045_10083.tif
#   inflating: Tp/Tp_D_CRN_M_N_arc00054_cha00085_11922.jpg
#   inflating: Tp/Tp_D_CRN_M_N_arc00071_arc00045_10085.tif
#   inflating: Tp/Tp_D_CRN_M_N_arc00073_arc00072_10267.tif
#   inflating: Tp/Tp_D_CRN_M_N_arc00088_arc00064_10394.tif
#   inflating: Tp/Tp_D_CRN_M_N_art00012_art00013_11812.jpg
#   inflating: Tp/Tp_D_CRN_M_N_art00014_art00013_11836.jpg
#   inflating: Tp/Tp_D_CRN_M_N_art00058_art00049_10529.tif
#   inflating: Tp/Tp_D_CRN_M_N_art00067_ani00093_11801.jpg
#   inflating: Tp/Tp_D_CRN_M_N_art00067_ani00095_11803.jpg
#   inflating: Tp/Tp_D_CRN_M_N_art00067_ani00096_11802.jpg
#   inflating: Tp/Tp_D_CRN_M_N_art00067_nat00013_11804.jpg
#   inflating: Tp/Tp_D_CRN_M_N_art00067_nat00059_11805.jpg
#   inflating: Tp/Tp_D_CRN_M_N_art00067_nat00095_11807.jpg
#   inflating: Tp/Tp_D_CRN_M_N_art00067_nat10122_11806.jpg
# ...

# %% [markdown]
# **Step: 6** Create CSV file for CASIA v2 Dataset.

# %%
from pylab import *
from sklearn import preprocessing
import sys
import shutil
import random
import os
import csv


def Make_CSV_file():
        forged_images_path =  '/content/drive/My Drive/Datasets/Tp'
        Not_forged_images_path =  '/content/drive/My Drive/Datasets/Au'
        forged = os.listdir(forged_images_path)
        Not_forged = os.listdir(Not_forged_images_path)
        file_number =random.randint(1, 1000000)
        print("Dataset prepared click Train to train the Model")
        CSV_file_name = "Casia_resaved"+".csv"
        with open(CSV_file_name, "w", encoding="utf-8", newline='') as new_file:
            csv_writer = csv.writer(new_file)
            for (i, file) in enumerate(forged):
              if not 'saved' in file:   
                  if 'Tp' in file:
                   csv_writer.writerow([forged_images_path+"/" + file, 1])
            for (i, file) in enumerate(Not_forged):
              if not 'saved' in file:   
                 if 'Au' in file:
                   csv_writer.writerow([Not_forged_images_path+"/" + file, 0])
                
            
            
        print("Done")


def main():
        Make_CSV_file()
        print("Csv file has been succesfully")
        

if __name__ == "__main__":
    main()
# Out:
# Dataset prepared click Train to train the Model
# Done
# Csv file has been succesfully

# %% [markdown]
# ELA pre-processing data

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.optimizers import RMSprop
from pylab import *
from PIL import Image, ImageChops, ImageEnhance
import pandas as pd
import numpy as np
import itertools
import matplotlib.pyplot as plt
import os
import random


def train_Ela_Model(csv_file , lr , ep):
    def convert_to_ela_image(path, quality):
        filename = path
        resaved_filename = filename.split('.')[0] + '.resaved.jpg'
        im = Image.open(filename).convert('RGB')
        im.save(resaved_filename, 'JPEG', quality=quality)
        resaved_im = Image.open(resaved_filename)
        ela_im = ImageChops.difference(im, resaved_im)
        extrema = ela_im.getextrema()
        max_diff = max([ex[1] for ex in extrema])
        if max_diff == 0:
            max_diff = 1
        scale = 255.0 / max_diff
        ela_im = ImageEnhance.Brightness(ela_im).enhance(scale)
        return ela_im


    dataset = pd.read_csv(csv_file)
    X = []
    Y = []
    for index, row in dataset.iterrows():
        X.append(array(convert_to_ela_image(row[0], 90).resize((128, 128))).flatten() / 255.0)
        Y.append(row[1])

    X = np.array(X)
    Y = to_categorical(Y, 2)
    X = X.reshape(-1, 128, 128, 3)
    X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.1, random_state=5, shuffle=True)

    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(5, 5), padding='valid', activation='relu', input_shape=(128, 128, 3)))
    model.add(Conv2D(filters=32, kernel_size=(5, 5), strides=(2, 2), padding='valid', activation='relu'))
    model.add(MaxPool2D(pool_size=2, strides=None, padding='valid', data_format='channels_last'))
    model.add(Dropout(0.25))

    model.add(Flatten())

    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.50))
    model.add(Dense(2, activation="softmax"))
    model.summary()

    optimizer = RMSprop(lr=lr, rho=0.9, epsilon=1e-08, decay=0.0)
    model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"])

    #early_stopping = EarlyStopping(monitor='val_acc', min_delta=0, patience=2, verbose=0, mode='auto')

    epochs = ep
    batch_size = 25

    history = model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, Y_val), verbose=2)

    fig, ax = plt.subplots(3, 1)
    ax[0].plot(history.history['loss'], color='b', label="Training loss")
    ax[0].plot(history.history['val_loss'], color='r', label="validation loss", axes=ax[0])
    legend = ax[0].legend(loc='best', shadow=True)

    ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
    ax[1].plot(history.history['val_accuracy'], color='r', label="Validation accuracy")
    legend_ = ax[1].legend(loc='best', shadow=True)


    def plot_confusion_matrix(cm_, classes, normalize=False, title_='Confusion matrix', cmap=cm.get_cmap("Spectral")):
        """
        This function prints and plots the confusion matrix.
        Normalization can be applied by setting `normalize=True`.
        """
        plt.imshow(cm_, interpolation='nearest', cmap=cmap)
        plt.title(title_)
        plt.colorbar()
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, classes)
        plt.yticks(tick_marks, classes)

        if normalize:
            cm_ = cm_.astype('float') / cm_.sum(axis=1)[:, np.newaxis]

        thresh = cm_.max() / 2.
        for i, j in itertools.product(range(cm_.shape[0]), range(cm_.shape[1])):
            plt.text(j, i, cm_[i, j],
                     horizontalalignment="center",
                     color="white" if cm_[i, j] > thresh else "black")

        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label')
            

    Y_pred = model.predict(X_val)
    Y_pred_classes = np.argmax(Y_pred, axis=1)
    Y_true = np.argmax(Y_val, axis=1)
    print("Training on MICC-F2000 dataset and Casia 2.0...")

    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)
    plot_confusion_matrix(confusion_mtx, classes=range(2))
    print("Please wait...")
    print("Creating Graph...")

    #plt.show()
    image_path = '/content/drive/My Drive/fyp/Ela'
    Models_path = '/content/drive/My Drive/fyp/Ela'
    file_number =random.randint(1, 1000000)
    plot_Name = image_path+"/ELA_Cas-3"+".png"
    Model_Name = Models_path+"/ELA_Cas"+".h5"
    print("Respective Folders has been created succesfully...")
    plt.savefig(plot_Name , transparent =True , bbox_incehs="tight" , pad_inches = 2 , dpi = 50)
    model.save(Model_Name)
    print("Done Training for Error level Analysis")
    return plot_Name , Model_Name


def main():
  print("Training has been started succesfully")
  plot , model = train_Ela_Model('/content/MICC-220-2000-f8_959574.csv' , 0.001 , 100)


if __name__ == "__main__":
  main()
# Out:
# Using TensorFlow backend.
# Training has been started succesfully
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 124, 124, 32)      2432
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 60, 60, 32)        25632
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 28800)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               7373056
# _________________________________________________________________
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.optimizers import RMSprop
from pylab import *
from PIL import Image, ImageChops, ImageEnhance
import pandas as pd
import numpy as np
import itertools
import matplotlib.pyplot as plt
import os
import random


def train_Ela_Model(csv_file , lr , ep):
    def convert_to_ela_image(path, quality):
        filename = path
        resaved_filename = filename.split('.')[0] + '.resaved.jpg'
        im = Image.open(filename).convert('RGB')
        im.save(resaved_filename, 'JPEG', quality=quality)
        resaved_im = Image.open(resaved_filename)
        ela_im = ImageChops.difference(im, resaved_im)
        extrema = ela_im.getextrema()
        max_diff = max([ex[1] for ex in extrema])
        if max_diff == 0:
            max_diff = 1
        scale = 255.0 / max_diff
        ela_im = ImageEnhance.Brightness(ela_im).enhance(scale)
        return ela_im


    dataset = pd.read_csv(csv_file)
    X = []
    Y = []
    for index, row in dataset.iterrows():
        X.append(array(convert_to_ela_image(row[0], 90).resize((128, 128))).flatten() / 255.0)
        Y.append(row[1])

    X = np.array(X)
    Y = to_categorical(Y, 2)
    X = X.reshape(-1, 128, 128, 3)
    X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.1, random_state=5, shuffle=True)

    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(5, 5), padding='valid', activation='relu', input_shape=(128, 128, 3)))
    model.add(Conv2D(filters=32, kernel_size=(5, 5), strides=(2, 2), padding='valid', activation='relu'))
    model.add(MaxPool2D(pool_size=2, strides=None, padding='valid', data_format='channels_last'))
    model.add(Dropout(0.25))

    model.add(Flatten())

    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.50))
    model.add(Dense(2, activation="softmax"))
    model.summary()

    optimizer = RMSprop(lr=lr, rho=0.9, epsilon=1e-08, decay=0.0)
    model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"])

    #early_stopping = EarlyStopping(monitor='val_acc', min_delta=0, patience=2, verbose=0, mode='auto')

    epochs = ep
    batch_size = 25

    history = model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, Y_val), verbose=2)

    fig, ax = plt.subplots(3, 1)
    ax[0].plot(history.history['loss'], color='b', label="Training loss")
    ax[0].plot(history.history['val_loss'], color='r', label="validation loss", axes=ax[0])
    legend = ax[0].legend(loc='best', shadow=True)

    ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
    ax[1].plot(history.history['val_accuracy'], color='r', label="Validation accuracy")
    legend_ = ax[1].legend(loc='best', shadow=True)


    def plot_confusion_matrix(cm_, classes, normalize=False, title_='Confusion matrix', cmap=cm.get_cmap("Spectral")):
        """
        This function prints and plots the confusion matrix.
        Normalization can be applied by setting `normalize=True`.
        """
        plt.imshow(cm_, interpolation='nearest', cmap=cmap)
        plt.title(title_)
        plt.colorbar()
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, classes)
        plt.yticks(tick_marks, classes)

        if normalize:
            cm_ = cm_.astype('float') / cm_.sum(axis=1)[:, np.newaxis]

        thresh = cm_.max() / 2.
        for i, j in itertools.product(range(cm_.shape[0]), range(cm_.shape[1])):
            plt.text(j, i, cm_[i, j],
                     horizontalalignment="center",
                     color="white" if cm_[i, j] > thresh else "black")

        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label')
            

    Y_pred = model.predict(X_val)
    Y_pred_classes = np.argmax(Y_pred, axis=1)
    Y_true = np.argmax(Y_val, axis=1)
    print("Training on MICC-F2000 dataset and Casia 2.0...")

    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)
    plot_confusion_matrix(confusion_mtx, classes=range(2))
    print("Please wait...")
    print("Creating Graph...")

    #plt.show()
    image_path = '/content/drive/My Drive/fyp/Ela'
    Models_path = '/content/drive/My Drive/fyp/Ela'
    file_number =random.randint(1, 1000000)
    plot_Name = image_path+"/ELA_CAsia"+".png"
    Model_Name = Models_path+"/ELA_Casia"+".h5"
    print("Respective Folders has been created succesfully...")
    plt.savefig(plot_Name , transparent =True , bbox_incehs="tight" , pad_inches = 2 , dpi = 50)
    model.save(Model_Name)
    print("Done Training for Error level Analysis")
    return plot_Name , Model_Name


def main():
  print("Training has been started succesfully")
  plot , model = train_Ela_Model('/content/Casia_PRE-Processed.csv' , 0.001 , 100)


if __name__ == "__main__":
  main()
# Out:
# Training has been started succesfully
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 2. Skipping tag 41487
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 41988
#   " Skipping tag %s" % (size, len(data), tag)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_3 (Conv2D)            (None, 124, 124, 32)      2432
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 60, 60, 32)        25632
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 30, 30, 32)        0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.optimizers import RMSprop
from pylab import *
from PIL import Image, ImageChops, ImageEnhance
import pandas as pd
import numpy as np
import itertools
import matplotlib.pyplot as plt
import os
import random


def train_Ela_Model(csv_file , lr , ep):
    def convert_to_ela_image(path, quality):
        filename = path
        resaved_filename = filename.split('.')[0] + '.resaved.jpg'
        im = Image.open(filename).convert('RGB')
        im.save(resaved_filename, 'JPEG', quality=quality)
        resaved_im = Image.open(resaved_filename)
        ela_im = ImageChops.difference(im, resaved_im)
        extrema = ela_im.getextrema()
        max_diff = max([ex[1] for ex in extrema])
        if max_diff == 0:
            max_diff = 1
        scale = 255.0 / max_diff
        ela_im = ImageEnhance.Brightness(ela_im).enhance(scale)
        return ela_im


    dataset = pd.read_csv(csv_file)
    X = []
    Y = []
    for index, row in dataset.iterrows():
        X.append(array(convert_to_ela_image(row[0], 90).resize((128, 128))).flatten() / 255.0)
        Y.append(row[1])

    X = np.array(X)
    Y = to_categorical(Y, 2)
    X = X.reshape(-1, 128, 128, 3)
    X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.1, random_state=5, shuffle=True)

    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(5, 5), padding='valid', activation='relu', input_shape=(128, 128, 3)))
    model.add(Conv2D(filters=32, kernel_size=(5, 5), strides=(2, 2), padding='valid', activation='relu'))
    model.add(MaxPool2D(pool_size=2, strides=None, padding='valid', data_format='channels_last'))
    model.add(Dropout(0.25))

    model.add(Flatten())

    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.50))
    model.add(Dense(2, activation="softmax"))
    model.summary()

    optimizer = RMSprop(lr=lr, rho=0.9, epsilon=1e-08, decay=0.0)
    model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"])

    #early_stopping = EarlyStopping(monitor='val_acc', min_delta=0, patience=2, verbose=0, mode='auto')

    epochs = ep
    batch_size = 48

    history = model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, Y_val), verbose=2)

    fig, ax = plt.subplots(3, 1)
    ax[0].plot(history.history['loss'], color='b', label="Training loss")
    ax[0].plot(history.history['val_loss'], color='r', label="validation loss", axes=ax[0])
    legend = ax[0].legend(loc='best', shadow=True)

    ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
    ax[1].plot(history.history['val_accuracy'], color='r', label="Validation accuracy")
    legend_ = ax[1].legend(loc='best', shadow=True)


    def plot_confusion_matrix(cm_, classes, normalize=False, title_='Confusion matrix', cmap=cm.get_cmap("Spectral")):
        """
        This function prints and plots the confusion matrix.
        Normalization can be applied by setting `normalize=True`.
        """
        plt.imshow(cm_, interpolation='nearest', cmap=cmap)
        plt.title(title_)
        plt.colorbar()
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, classes)
        plt.yticks(tick_marks, classes)

        if normalize:
            cm_ = cm_.astype('float') / cm_.sum(axis=1)[:, np.newaxis]

        thresh = cm_.max() / 2.
        for i, j in itertools.product(range(cm_.shape[0]), range(cm_.shape[1])):
            plt.text(j, i, cm_[i, j],
                     horizontalalignment="center",
                     color="white" if cm_[i, j] > thresh else "black")

        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label')
            

    Y_pred = model.predict(X_val)
    Y_pred_classes = np.argmax(Y_pred, axis=1)
    Y_true = np.argmax(Y_val, axis=1)
    print("Training on Casia 2.0...")

    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)
    plot_confusion_matrix(confusion_mtx, classes=range(2))
    print("Please wait...")
    print("Creating Graph...")

    #plt.show()
    image_path = '/content/drive/My Drive/fyp/Ela'
    Models_path = '/content/drive/My Drive/fyp/Ela'
    file_number =random.randint(1, 1000000)
    plot_Name = image_path+"/ELA_Cas-o-j"+".png"
    Model_Name = Models_path+"/ELA_Cas-o-j"+".h5"
    print("Respective Folders has been created succesfully...")
    plt.savefig(plot_Name , transparent =True , bbox_incehs="tight" , pad_inches = 2 , dpi = 50)
    model.save(Model_Name)
    print("Done Training for Error level Analysis")
    return plot_Name , Model_Name


def main():
  print("Training has been started succesfully")
  plot , model = train_Ela_Model('/content/Casia_CSV.csv' , 0.001 , 55)


if __name__ == "__main__":
  main()
# Out:
# Training has been started succesfully
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 2. Skipping tag 41487
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 41988
#   " Skipping tag %s" % (size, len(data), tag)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_3 (Conv2D)            (None, 124, 124, 32)      2432
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 60, 60, 32)        25632
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 30, 30, 32)        0
# ...

# %% [markdown]
# **Step: 7** Train pre-built Model VGG16 from keras on MICC-F2000 Dataset which returns you graph plot .png file with confusion matrix and VGG16 Trained model .h5 with 100% accuracy.

# %%
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from pylab import *
import numpy as np
import matplotlib.pyplot as plt
from keras import models
from keras import layers
import itertools
from sklearn.metrics import confusion_matrix
from keras import optimizers
from PIL import Image
import pandas as pd
from keras.applications.vgg16 import VGG16
import os
import random

def train_VGG16_Model(csv_file , lr , ep):
    def Read_image(path):
      image = Image.open(path).convert('RGB')
      return image

    X = []
    Y = []
    dataset = pd.read_csv(csv_file)
    for index, row in dataset.iterrows():
        X.append(array(Read_image(row[0]).resize((100, 100))).flatten() / 255.0)
        Y.append(row[1])

    X = np.array(X)
    Y = to_categorical(Y, 2)
    X = X.reshape(-1, 100, 100, 3)

    X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.20, random_state=10)

    vgg_conv = VGG16(weights='imagenet', include_top=False, input_shape=(100, 100, 3))

    model = models.Sequential()
    #Note
    for layer in vgg_conv.layers[:-5]:
        layer.trainable = False

    for layer in vgg_conv.layers:
        print(layer, layer.trainable)

    model.add(vgg_conv)
    model.add(layers.Flatten())
    model.add(layers.Dense(1024, activation='relu'))
    model.add(layers.Dropout(0.25))
    model.add(layers.Dense(2, activation='softmax'))

    model.compile(loss='binary_crossentropy',
                  optimizer=optimizers.RMSprop(lr=lr),
                  metrics=['accuracy'])
    epochs = ep
    batch_size = 64

    history = model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, Y_val),verbose=2)
    fig, ax = plt.subplots(3, 1)
    ax[0].plot(history.history['loss'], color='b', label="Training loss")
    ax[0].plot(history.history['val_loss'], color='r', label="validation loss", axes=ax[0])
    legend = ax[0].legend(loc='best', shadow=True)

    ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
    ax[1].plot(history.history['val_accuracy'], color='r', label="Validation accuracy")
    legend = ax[1].legend(loc='best', shadow=True)

    def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
        plt.imshow(cm, interpolation='nearest', cmap=cmap)
        plt.title(title)
        plt.colorbar()
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, classes, rotation=45)
        plt.yticks(tick_marks, classes)

        if normalize:
            cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

        thresh = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, cm[i, j], horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

    # Predict the values from the validation dataset
    Y_pred = model.predict(X_val)
    # Convert predictions classes to one hot vectors
    Y_pred_classes = np.argmax(Y_pred, axis=1)
    # Convert validation observations to one hot vectors
    Y_true = np.argmax(Y_val, axis=1)
    # compute the confusion matrix
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)
    # plot the confusion matrix
    plot_confusion_matrix(confusion_mtx, classes=range(2))

    image_path = '/content/drive/My Drive/fyp/VGG16'
    Models_path = '/content/drive/My Drive/fyp/VGG16'
    file_number =random.randint(1, 1000000)
    plot_Name = image_path+"/VGG16_MICCF2000"+".jpg"
    Model_Name = Models_path+"/VGG16_MICCF2000"+".h5"
    plt.savefig(plot_Name , transparent =True , bbox_incehs="tight" , pad_inches = 2 , dpi = 50)
    model.save(Model_Name)
    return plot_Name , Model_Name


def main():
  print("Training has been started succesfully")
  plot , model = train_VGG16_Model('/content/MICC-f2000_489026.csv' , 0.0001 , 150)


if __name__ == "__main__":
  main()
# Out:
# Training has been started succesfully
# <keras.engine.input_layer.InputLayer object at 0x7f71200ceb00> False
# <keras.layers.convolutional.Conv2D object at 0x7f71200cec50> False
# <keras.layers.convolutional.Conv2D object at 0x7f71200cedd8> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f71200b7400> False
# <keras.layers.convolutional.Conv2D object at 0x7f71200b7240> False
# <keras.layers.convolutional.Conv2D object at 0x7f71200b7f28> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f71200bcac8> False
# <keras.layers.convolutional.Conv2D object at 0x7f71200bc908> False
# <keras.layers.convolutional.Conv2D object at 0x7f70d58845f8> False
# <keras.layers.convolutional.Conv2D object at 0x7f70d5884f28> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f70d5888c18> False
# <keras.layers.convolutional.Conv2D object at 0x7f70d5888a58> False
# <keras.layers.convolutional.Conv2D object at 0x7f70d5890748> False
# ...

# %% [markdown]
# **Step: 8** Train pre-built Model VGG19 from keras on MICC-F2000 Dataset which returns you graph plot .png file with confusion matrix and VGG16 Trained model .h5 with 100% accuracy.

# %%
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from pylab import *
from keras.callbacks import LearningRateScheduler
from keras import models
from keras import layers
import numpy as np
import matplotlib.pyplot as plt
from keras.applications.vgg19 import VGG19
import itertools
from sklearn.metrics import confusion_matrix
from keras import optimizers
from PIL import Image
import random
import pandas as pd
import os

def train_VGG19_Model(csv_file , lr , ep):
    def step_decay_schedule(initial_lr=1e-3, decay_factor=0.75, step_size=10):
        def schedule(epoch):
            return initial_lr * (decay_factor ** np.floor(epoch / step_size))
        return LearningRateScheduler(schedule)


    def Read_image(path):
        im = Image.open(path).convert('RGB')
        return im


    X = []
    Y = []
    dataset = pd.read_csv(csv_file)
    for index, row in dataset.iterrows():
        X.append(array(Read_image(row[0]).resize((100, 100))).flatten() / 255.0)
        Y.append(row[1])

    X = np.array(X)
    Y = to_categorical(Y, 2)
    X = X.reshape(-1, 100, 100, 3)
    X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.20, random_state=5)

    # Load the VGG model
    vgg_conv = VGG19(weights='imagenet', include_top=False, input_shape=(100, 100, 3))

    # Create the model
    model = models.Sequential()
    # Freeze the layers  the first layers
    for layer in vgg_conv.layers[:-5]:
        layer.trainable = False

    # Check the trainabl status of the individual layers
    for layer in vgg_conv.layers:
        print(layer, layer.trainable)



    model.add(vgg_conv)
    model.summary()
    model.add(layers.Flatten())
    model.add(layers.Dense(1024, activation='relu'))
    model.add(layers.Dropout(0.50))
    model.add(layers.Dense(1024, activation='relu'))
    model.add(layers.Dropout(0.50))
    model.add(layers.Dense(2, activation='softmax'))

    optimizer = optimizers.Adagrad(lr = lr, epsilon = 1e-07, decay = 0.0)
    model.compile(optimizer=optimizer,
                  loss="mean_squared_error",
                  metrics=["accuracy"])

    lr_sched = step_decay_schedule(initial_lr=1e-4, decay_factor=0.75, step_size=2)

    epochs = ep
    batch_size = 200

    history = model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, Y_val), verbose=1,callbacks=[lr_sched])
    # Plot the loss and accuracy curves for training and validation
    fig, ax = plt.subplots(3, 1)
    ax[0].plot(history.history['loss'], color='b', label="Training loss")
    ax[0].plot(history.history['val_loss'], color='r', label="validation loss", axes=ax[0])
    legend = ax[0].legend(loc='best', shadow=True)

    ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
    ax[1].plot(history.history['val_accuracy'], color='r', label="Validation accuracy")
    legend = ax[1].legend(loc='best', shadow=True)


    def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
        plt.imshow(cm, interpolation='nearest', cmap=cmap)
        plt.title(title)
        plt.colorbar()
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, classes, rotation=45)
        plt.yticks(tick_marks, classes)

        if normalize:
            cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

        thresh = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, cm[i, j], horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

    # Predict the values from the validation dataset
    Y_pred = model.predict(X_val)
    # Convert predictions classes to one hot vectors
    Y_pred_classes = np.argmax(Y_pred, axis=1)
    # Convert validation observations to one hot vectors
    Y_true = np.argmax(Y_val, axis=1)
    # compute the confusion matrix
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)
    # plot the confusion matrix
    plot_confusion_matrix(confusion_mtx, classes=range(2))

    image_path = '/content/drive/My Drive/fyp/VGG19'
    Models_path = '/content/drive/My Drive/fyp/VGG19'
    file_number =random.randint(1, 1000000)
    plot_Name = image_path+"/VGG19_Sg-Main"+".jpg"
    Model_Name = Models_path+"/VGG19_Sg-MAIN"+".h5"
    plt.savefig(plot_Name , transparent =True , bbox_incehs="tight" , pad_inches = 2 , dpi = 50)
    model.save(Model_Name)
    return plot_Name , Model_Name
 

def main():
    print("Training has been started succesfully")
    plot , model = train_VGG19_Model('/content/Casia_PRE-Processed.csv' , 0.001 , 155)
     

if __name__ == "__main__": 
  main()
# Out:
# Using TensorFlow backend.
# Training has been started succesfully
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 2. Skipping tag 41487
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 41988
#   " Skipping tag %s" % (size, len(data), tag)
# <keras.engine.input_layer.InputLayer object at 0x7f2eeb2a8748> False
# <keras.layers.convolutional.Conv2D object at 0x7f2eac582978> False
# <keras.layers.convolutional.Conv2D object at 0x7f2eac582278> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f2eac582ba8> False
# <keras.layers.convolutional.Conv2D object at 0x7f2eac582748> False
# <keras.layers.convolutional.Conv2D object at 0x7f2eac4c0c88> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f2eac4e7828> False
# ...

# %%
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from pylab import *
from keras.callbacks import LearningRateScheduler
from keras import models
from keras import layers
import numpy as np
import matplotlib.pyplot as plt
from keras.applications.vgg19 import VGG19
import itertools
from sklearn.metrics import confusion_matrix
from keras import optimizers
from PIL import Image
import random
import pandas as pd
import os

def train_VGG19_Model(csv_file , lr , ep):
    def step_decay_schedule(initial_lr=1e-3, decay_factor=0.75, step_size=10):
        def schedule(epoch):
            return initial_lr * (decay_factor ** np.floor(epoch / step_size))
        return LearningRateScheduler(schedule)


    def Read_image(path):
        im = Image.open(path).convert('RGB')
        return im


    X = []
    Y = []
    dataset = pd.read_csv(csv_file)
    for index, row in dataset.iterrows():
        X.append(array(Read_image(row[0]).resize((100, 100))).flatten() / 255.0)
        Y.append(row[1])

    X = np.array(X)
    Y = to_categorical(Y, 2)
    X = X.reshape(-1, 100, 100, 3)
    X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.30, random_state=5)

    # Load the VGG model
    vgg_conv = VGG19(weights='imagenet', include_top=False, input_shape=(100, 100, 3))

    # Create the model
    model = models.Sequential()
    # Freeze the layers  the first layers
    for layer in vgg_conv.layers[:-5]:
        layer.trainable = False

    # Check the trainabl status of the individual layers
    for layer in vgg_conv.layers:
        print(layer, layer.trainable)



    model.add(vgg_conv)
    model.summary()
    model.add(layers.Flatten())
    model.add(layers.Dense(1024, activation='relu'))
    model.add(layers.Dropout(0.50))
    model.add(layers.Dense(1024, activation='relu'))
    model.add(layers.Dropout(0.50))
    model.add(layers.Dense(2, activation='softmax'))

    optimizer = optimizers.Adagrad(lr=0.0005, epsilon=1e-07, decay=0.0)
    model.compile(optimizer=optimizer,
                  loss="mean_squared_error",
                  metrics=["accuracy"])

    lr_sched = step_decay_schedule(initial_lr=1e-4, decay_factor=0.75, step_size=2)

    epochs = ep
    batch_size = 20

    history = model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_val, Y_val), verbose=2,callbacks=[lr_sched])
    # Plot the loss and accuracy curves for training and validation
    fig, ax = plt.subplots(3, 1)
    ax[0].plot(history.history['loss'], color='b', label="Training loss")
    ax[0].plot(history.history['val_loss'], color='r', label="validation loss", axes=ax[0])
    legend = ax[0].legend(loc='best', shadow=True)

    ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
    ax[1].plot(history.history['val_accuracy'], color='r', label="Validation accuracy")
    legend = ax[1].legend(loc='best', shadow=True)

    def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
        plt.imshow(cm, interpolation='nearest', cmap=cmap)
        plt.title(title)
        plt.colorbar()
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, classes, rotation=45)
        plt.yticks(tick_marks, classes)

        if normalize:
            cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

        thresh = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, cm[i, j], horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

    # Predict the values from the validation dataset
    Y_pred = model.predict(X_val)
    # Convert predictions classes to one hot vectors
    Y_pred_classes = np.argmax(Y_pred, axis=1)
    # Convert validation observations to one hot vectors
    Y_true = np.argmax(Y_val, axis=1)
    # compute the confusion matrix
    confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)
    # plot the confusion matrix
    plot_confusion_matrix(confusion_mtx, classes=range(2))

    image_path = '/content/drive/My Drive/FYP-3/VGG19'
    Models_path = '/content/drive/My Drive/FYP-3/VGG19'
    file_number =random.randint(1, 1000000)
    plot_Name = image_path+"/VGG19ain"+".jpg"
    Model_Name = Models_path+"/VGG19AIN"+".h5"
    plt.savefig(plot_Name , transparent =True , bbox_incehs="tight" , pad_inches = 2 , dpi = 50)
    model.save(Model_Name)
    return plot_Name , Model_Name
 

def main():
    print("Training has been started succesfully")
    plot , model = train_VGG19_Model('/content/Casia_resaved.csv' , 0.0005 , 25)
     

if __name__ == "__main__": 
  main()
# Out:
# Training has been started succesfully
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 2. Skipping tag 41487
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 41988
#   " Skipping tag %s" % (size, len(data), tag)
# ...
# 80142336/80134624 [==============================] - 1s 0us/step
# <keras.engine.input_layer.InputLayer object at 0x7fc2838a4780> False
# <keras.layers.convolutional.Conv2D object at 0x7fc28353ce80> False
# <keras.layers.convolutional.Conv2D object at 0x7fc28353c6a0> False
# <keras.layers.pooling.MaxPooling2D object at 0x7fc28353ceb8> False
# <keras.layers.convolutional.Conv2D object at 0x7fc28353cd30> False
# <keras.layers.convolutional.Conv2D object at 0x7fc2834ccbe0> False
# ...
